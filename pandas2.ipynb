# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df["deck"].notna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
x = df.columns
y = [i for i in x]
y
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.notna()
# Out:
#      survived  pclass   sex    age  sibsp  parch  fare  embarked  class   who  \
# 0        True    True  True   True   True   True  True      True   True  True
# 1        True    True  True   True   True   True  True      True   True  True
# 2        True    True  True   True   True   True  True      True   True  True
# 3        True    True  True   True   True   True  True      True   True  True
# 4        True    True  True   True   True   True  True      True   True  True
# ..        ...     ...   ...    ...    ...    ...   ...       ...    ...   ...
# 886      True    True  True   True   True   True  True      True   True  True
# 887      True    True  True   True   True   True  True      True   True  True
# 888      True    True  True  False   True   True  True      True   True  True
# 889      True    True  True   True   True   True  True      True   True  True
# 890      True    True  True   True   True   True  True      True   True  True
#
# ...

# %%
df.iloc[10:25,3:8]
# Out:
#      age  sibsp  parch     fare embarked
# 10   4.0      1      1  16.7000        S
# 11  58.0      0      0  26.5500        S
# 12  20.0      0      0   8.0500        S
# 13  39.0      1      5  31.2750        S
# 14  14.0      0      0   7.8542        S
# 15  55.0      0      0  16.0000        S
# 16   2.0      4      1  29.1250        Q
# 17   NaN      0      0  13.0000        S
# 18  31.0      1      0  18.0000        S
# 19   NaN      0      0   7.2250        C
# 20  35.0      0      0  26.0000        S
# 21  34.0      0      0  13.0000        S
# 22  15.0      0      0   8.0292        Q
# 23  28.0      0      0  35.5000        S
# 24   8.0      3      1  21.0750        S

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.iloc[[3,5,8],2:8]
# Out:
#       sex   age  sibsp  parch     fare embarked
# 3  female  35.0      1      0  53.1000        S
# 5    male   NaN      0      0   8.4583        Q
# 8  female  27.0      0      2  11.1333        S

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[df["survived"]==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[: , ["survived","age"]]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.set_index()

# %%
df2 = pd.read_csv("../UNZIP_FOR_NOTEBOOKS_FINAL/DATA/tips.csv")

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df2 = df2.set_index("Payment ID")

# %%
df2.loc["Sun2959"]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df2.loc[["Sun2959","Sun5260"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df2 = df2.reset_index()

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
np.empty((5,5)).mean()
# Out:
# 9.21570262996e-312

# %%
np.std(np.empty((5,5)))
# Out:
# 0.0

# %%
np.std(np.empty((10,20)))
# Out:
# 0.0

# %%
np.empty((5,5))[0]
# Out:
# array([9.21570137e-312, 9.21570137e-312, 9.21570137e-312, 9.21570137e-312,
#        9.21570137e-312])

# %%
np.empty((10,5),int)
# Out:
# array([[1194195056,        434, 1194194736,        434, 1194194736],
#        [       434, 1194195056,        434, 1194195056,        434],
#        [1005270576,        434, 1005270576,        434, 1005270576],
#        [       434, 1005273840,        434, 1008523824,        434],
#        [1194195696,        434, 1194193072,        434, 1194193072],
#        [       434, 1194195696,        434, 1194195696,        434],
#        [1194238000,        434, 1194238000,        434, 1194238000],
#        [       434, 1194241456,        434, 1194258288,        434],
#        [1194249840,        434, 1194247728,        434, 1194249840],
#        [       434, 1194247728,        434, 1194249840,        434]])

# %%
np.std(np.empty((10,5)))
# Out:
# 0.0

# %%
df3 = df2.iloc[:10]
df4 = df.iloc[:10]
df3.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df4.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df3.reindex(df3["CC Number"])
# Out:
#                  Payment ID  total_bill  tip  sex smoker  day time  size  \
# CC Number
# 3560325168603410        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 4478071379779230        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 6011812112971322        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 4676137647685994        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 4832732618637221        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 213140353657882         NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 2223727524230344        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 3514785077705092        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 3522866365840377        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
# 3532124519049786        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN
#
#                   price_per_person Payer Name  CC Number
# CC Number
# 3560325168603410               NaN        NaN        NaN
# ...

# %%
df2["tip percentage"] = 100*df2["tip"] / df2["total_bill"]

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage
# ...

# %%
type(df2["tip percentage"])
# Out:
# pandas.core.series.Series

# %%
df2["yeni kolon"] = np.arange(244)

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2["tip percentage"] = np.round(df2["tip percentage"],2)

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
# 2              7.00      Travis Walters  6011812112971322            17.0
# 3             11.84    Nathaniel Harris  4676137647685994            14.0
# 4              6.15        Tonya Carter  4832732618637221            15.0
#
#    yeni kolon
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
df2.drop("yeni kolon", axis=1)
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage
# ...

# %%
df2.drop(columns="yeni kolon")
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage
# ...

# %%
df2.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
# 2              7.00      Travis Walters  6011812112971322            17.0
# 3             11.84    Nathaniel Harris  4676137647685994            14.0
# 4              6.15        Tonya Carter  4832732618637221            15.0
#
#    yeni kolon
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
df2.shape
# Out:
# (244, 13)

# %%
df2.tail()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person       Payer Name         CC Number  tip percentage  \
# 239              9.68    Michael Avila  5296068606052842            20.0
# 240             13.59   Monica Sanders  3506806155565404             7.0
# 241             11.34       Keith Wong  6011891618747196             9.0
# 242              8.91     Dennis Dixon     4375220550950            10.0
# 243              9.39  Michelle Hardin  3511451626698139            16.0
#
#      yeni kolon
# 239         239
# 240         240
# 241         241
# 242         242
# 243         243

# %%
df2.append(df2.iloc[0]).tail()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# 240             13.59      Monica Sanders  3506806155565404             7.0
# 241             11.34          Keith Wong  6011891618747196             9.0
# 242              8.91        Dennis Dixon     4375220550950            10.0
# 243              9.39     Michelle Hardin  3511451626698139            16.0
# 0                8.49  Christy Cunningham  3560325168603410             6.0
#
#      yeni kolon
# 240         240
# 241         241
# 242         242
# 243         243
# ...

# %%
df2.append(df2.iloc[0])
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2[df2["day"].isin(["Sun","Sat","Thur"])]
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2.drop(df2.index[-1])
# Out:
#     Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...         ...   ...     ...    ...  ...     ...   ...
# 238    Sat9777       35.83  4.67  Female     No  Sat  Dinner     3
# 239    Sat2657       29.03  5.92    Male     No  Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# 0                8.49  Christy Cunningham  3560325168603410             6.0
# ...

# %%
df2.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
# 2              7.00      Travis Walters  6011812112971322            17.0
# 3             11.84    Nathaniel Harris  4676137647685994            14.0
# 4              6.15        Tonya Carter  4832732618637221            15.0
#
#    yeni kolon
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Payment ID        244 non-null    object
#  1   total_bill        244 non-null    float64
#  2   tip               244 non-null    float64
#  3   sex               244 non-null    object
#  4   smoker            244 non-null    object
#  5   day               244 non-null    object
#  6   time              244 non-null    object
#  7   size              244 non-null    int64
#  8   price_per_person  244 non-null    float64
#  9   Payer Name        244 non-null    object
#  10  CC Number         244 non-null    int64
#  11  tip percentage    244 non-null    float64
#  12  yeni kolon        244 non-null    int32
# dtypes: float64(4), int32(1), int64(2), object(6)
# memory usage: 24.0+ KB

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(736758921)
# Out:
# '8921'

# %%
df2["last_4"] = df2["CC Number"].apply(last_four)
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2["last_5"] = df2["CC Number"].apply(lambda x: str(x)[-5:])
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
def yelp(price):
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
def quality(tot,tip):
    if tip/tot > 0.25: return "Generous"
    else: return "Other"

# %%
df2.head(2)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
#
#    yeni kolon last_4 last_5
# 0           0   3410  03410
# 1           1   9230  79230

# %%
df2[["total_bill","tip"]].apply(lambda x: quality(x["total_bill"],x["tip"]),axis=1)
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Length: 244, dtype: object

# %%
df2["new"]=df2[["total_bill","tip"]].apply(lambda x: quality(x["total_bill"],x["tip"]),axis=1)

# %%
df2.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
# 2              7.00      Travis Walters  6011812112971322            17.0
# 3             11.84    Nathaniel Harris  4676137647685994            14.0
# 4              6.15        Tonya Carter  4832732618637221            15.0
#
#    yeni kolon last_4 last_5    new
# 0           0   3410  03410  Other
# 1           1   9230  79230  Other
# ...

# %%
np.vectorize(quality)(df2["total_bill"],df2["tip"])
# Out:
# array(['Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Generous', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Generous', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
# ...

# %%
np.array(df2[["total_bill","tip"]].apply(lambda x: quality(x["total_bill"],x["tip"]),axis=1),dtype='<U8')
# Out:
# array(['Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Generous', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Generous', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
#        'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other',
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dict(df.loc[1])
# Out:
# {'survived': 1,
#  'pclass': 1,
#  'sex': 'female',
#  'age': 38.0,
#  'sibsp': 1,
#  'parch': 0,
#  'fare': 71.2833,
#  'embarked': 'C',
#  'class': 'First',
#  'who': 'woman',
#  'adult_male': False,
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'alive': 'yes',
#  'alone': False}

# %%
pd.Series?

# %%
s = pd.Series(" ".join("deneme").split(),index=np.arange(7,13))

# %%
s.index[0]
# Out:
# 7

# %%
s.keys()
# Out:
# Int64Index([7, 8, 9, 10, 11, 12], dtype='int64')

# %%
s.index
# Out:
# Int64Index([7, 8, 9, 10, 11, 12], dtype='int64')

# %%
s.items
# Out:
# <bound method Series.items of 7     d
# 8     e
# 9     n
# 10    e
# 11    m
# 12    e
# dtype: object>

# %%
s
# Out:
# 7     d
# 8     e
# 9     n
# 10    e
# 11    m
# 12    e
# dtype: object

# %%
df = pd.DataFrame(index=[s,s])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [(d, d), (e, e), (n, n), (e, e), (m, m), (e, e)]

# %%
df = pd.DataFrame(columns=[s,s])
df
# Out:
# Empty DataFrame
# Columns: [(d, d), (e, e), (n, n), (e, e), (m, m), (e, e)]
# Index: []

# %%
df = pd.DataFrame(data = [s,s]).T
df
# Out:
#     0  1
# 7   d  d
# 8   e  e
# 9   n  n
# 10  e  e
# 11  m  m
# 12  e  e

# %%
df = pd.DataFrame(data = [s,s]).rename_axis(columns=["s1","s2","s3","s4","s5","s6"])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12540/1527691971.py in <module>
# ----> 1 df = pd.DataFrame(data = [s,s]).rename_axis(columns=["s1","s2","s3","s4","s5","s6"])
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in rename_axis(self, mapper, **kwargs)
#    1331                     curnames = self._get_axis(axis).names
#    1332                     newnames = [f(name) for name in curnames]
# -> 1333                 result._set_axis_name(newnames, axis=axis, inplace=True)
# ...

# %%
df = pd.DataFrame(data = [s,s])
df.rename_axis(columns=["s1","s2","s3","s4","s5","s6"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12540/2229382973.py in <module>
#       1 df = pd.DataFrame(data = [s,s])
# ----> 2 df.rename_axis(columns=["s1","s2","s3","s4","s5","s6"])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in rename_axis(self, mapper, **kwargs)
#    1331                     curnames = self._get_axis(axis).names
#    1332                     newnames = [f(name) for name in curnames]
# -> 1333                 result._set_axis_name(newnames, axis=axis, inplace=True)
# ...

# %%
df = pd.DataFrame(data = [s,s])
df.rename(index={0:3,1:4})
# Out:
#   7  8  9  10 11 12
# 3  d  e  n  e  m  e
# 4  d  e  n  e  m  e

# %%
df.rename(columns = {'var1':'new_col1', 'var2':'new_col2'}, inplace = True)

# %%
df2
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip percentage  \
# ...

# %%
df2.sample(frac=1)
# Out:
#     Payment ID  total_bill  tip     sex smoker   day    time  size  \
# 98      Fri144       21.01  3.0    Male    Yes   Fri  Dinner     2
# 217    Sat8489       11.59  1.5    Male    Yes   Sat  Dinner     2
# 52     Sun6165       34.81  5.2  Female     No   Sun  Dinner     4
# 231    Sat6334       15.69  3.0    Male    Yes   Sat  Dinner     3
# 154    Sun5814       19.77  2.0    Male     No   Sun  Dinner     4
# ..         ...         ...  ...     ...    ...   ...     ...   ...
# 145   Thur9331        8.35  1.5  Female     No  Thur   Lunch     2
# 73     Sat6065       25.28  5.0  Female    Yes   Sat  Dinner     2
# 182    Sun2337       45.35  3.5    Male    Yes   Sun  Dinner     3
# 112     Sun591       38.07  4.0    Male     No   Sun  Dinner     3
# 83    Thur8801       32.68  5.0    Male    Yes  Thur   Lunch     2
#
#      price_per_person     Payer Name         CC Number  tip percentage  \
# 98              10.50     Michael Li  4831801127457917            14.0
# ...

# %%
df2.sample(n=3,random_state=2)
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 54     Sun9470       25.56  4.34    Male     No   Sun  Dinner     4
# 126   Thur6719        8.52  1.48    Male     No  Thur   Lunch     2
#
#      price_per_person      Payer Name         CC Number  tip percentage  \
# 85               8.71     Shawna Cook  6011787464177340            15.0
# 54               6.39    Ronald Owens  6569607991983380            17.0
# 126              4.26  Mario Bradshaw  4524404353861811            17.0
#
#      yeni kolon last_4 last_5    new
# 85           85   7340  77340  Other
# 54           54   3380  83380  Other
# 126         126   1811  61811  Other

# %%
df2.sample(frac=1,axis=1).sample(frac=1)
# Out:
#       tip        Payer Name   day  size     sex         CC Number last_4  \
# 3    3.31  Nathaniel Harris   Sun     2    Male  4676137647685994   5994
# 2    3.50    Travis Walters   Sun     3    Male  6011812112971322   1322
# 85   5.17       Shawna Cook  Thur     4  Female  6011787464177340   7340
# 179  3.55      Brian Bailey   Sun     2    Male   346656312114848   4848
# 139  2.75     Lindsey Meyer  Thur     2  Female      676239597203   7203
# ..    ...               ...   ...   ...     ...               ...    ...
# 142  5.00      Eric Andrews  Thur     5    Male  4356531761046453   6453
# 110  3.00     James Sanchez   Sat     2    Male   345243048851323   1323
# 32   3.00     Amanda Wilson   Sat     2  Female   213186304291560   1560
# 164  3.00    Audrey Griffin   Sun     2  Female  3500853929693258   3258
# 219  3.09      Shelby House   Sat     4  Female      502097403252   3252
#
#     Payment ID    time last_5  total_bill    new  tip percentage smoker  \
# ...

# %%
df2.size
# Out:
# 3904

# %%
244*16
# Out:
# 3904

# %%
df2.reset_index().reset_index()
# Out:
#      level_0  index Payment ID  total_bill   tip     sex smoker   day    time  \
# 0          0      0    Sun2959       16.99  1.01  Female     No   Sun  Dinner
# 1          1      1    Sun4608       10.34  1.66    Male     No   Sun  Dinner
# 2          2      2    Sun4458       21.01  3.50    Male     No   Sun  Dinner
# 3          3      3    Sun5260       23.68  3.31    Male     No   Sun  Dinner
# 4          4      4    Sun2251       24.59  3.61  Female     No   Sun  Dinner
# ..       ...    ...        ...         ...   ...     ...    ...   ...     ...
# 239      239    239    Sat2657       29.03  5.92    Male     No   Sat  Dinner
# 240      240    240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner
# 241      241    241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner
# 242      242    242      Sat17       17.82  1.75    Male     No   Sat  Dinner
# 243      243    243    Thur672       18.78  3.00  Female     No  Thur  Dinner
#
# ...

# %%
df2.set_index("Payment ID")
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df2.loc[df2.total_bill<10]
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 6      Sun5985        8.77  2.00    Male     No   Sun  Dinner     2
# 30     Sat4099        9.55  1.45    Male     No   Sat  Dinner     2
# 43     Sun3279        9.68  1.32    Male     No   Sun  Dinner     2
# 53     Sun4561        9.94  1.56    Male     No   Sun  Dinner     2
# 67     Sat3455        3.07  1.00  Female    Yes   Sat  Dinner     1
# 92     Fri3780        5.75  1.00  Female    Yes   Fri  Dinner     2
# 111    Sat4801        7.25  1.00  Female     No   Sat  Dinner     1
# 126   Thur6719        8.52  1.48    Male     No  Thur   Lunch     2
# 135   Thur6600        8.51  1.25  Female     No  Thur   Lunch     2
# 145   Thur9331        8.35  1.50  Female     No  Thur   Lunch     2
# 148   Thur7276        9.78  1.73    Male     No  Thur   Lunch     2
# 149   Thur6321        7.51  2.00    Male     No  Thur   Lunch     2
# 172    Sun9209        7.25  5.15    Male    Yes   Sun  Dinner     2
# ...

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
type(data["X"])
# Out:
# pandas.core.series.Series

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Payment ID        244 non-null    object
#  1   total_bill        244 non-null    float64
#  2   tip               244 non-null    float64
#  3   sex               244 non-null    object
#  4   smoker            244 non-null    object
#  5   day               244 non-null    object
#  6   time              244 non-null    object
#  7   size              244 non-null    int64
#  8   price_per_person  244 non-null    float64
#  9   Payer Name        244 non-null    object
#  10  CC Number         244 non-null    int64
#  11  tip percentage    244 non-null    float64
#  12  yeni kolon        244 non-null    int32
#  13  last_4            244 non-null    object
#  14  last_5            244 non-null    object
#  15  new               244 non-null    object
# ...

# %%
df2;df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Payment ID        244 non-null    object
#  1   total_bill        244 non-null    float64
#  2   tip               244 non-null    float64
#  3   sex               244 non-null    object
#  4   smoker            244 non-null    object
#  5   day               244 non-null    object
#  6   time              244 non-null    object
#  7   size              244 non-null    int64
#  8   price_per_person  244 non-null    float64
#  9   Payer Name        244 non-null    object
#  10  CC Number         244 non-null    int64
#  11  tip percentage    244 non-null    float64
#  12  yeni kolon        244 non-null    int32
#  13  last_4            244 non-null    object
#  14  last_5            244 non-null    object
#  15  new               244 non-null    object
# ...

# %%
df2.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df2.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip percentage  \
# 0              8.49  Christy Cunningham  3560325168603410             6.0
# 1              3.45      Douglas Tucker  4478071379779230            16.0
# 2              7.00      Travis Walters  6011812112971322            17.0
# 3             11.84    Nathaniel Harris  4676137647685994            14.0
# 4              6.15        Tonya Carter  4832732618637221            15.0
#
#    yeni kolon last_4 last_5    new
# 0           0   3410  03410  Other
# 1           1   9230  79230  Other
# ...

# %%
df2.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df.isnull().sum()
# Out:
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    0
# dtype: int64

# %%
df2[df2.isnull()]
# Out:
#     Payment ID  total_bill  tip  sex smoker  day time  size  price_per_person  \
# 0          NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 1          NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 2          NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 3          NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 4          NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# ..         ...         ...  ...  ...    ...  ...  ...   ...               ...
# 239        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 240        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 241        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 242        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
# 243        NaN         NaN  NaN  NaN    NaN  NaN  NaN   NaN               NaN
#
# ...

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.deck.isnull().sum()
# Out:
# 688

# %%
df.deck.notnull().sum()
# Out:
# 203

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.notnull().sum()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop(index = 2)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["pclass"].str

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001
